# %% [markdown]
# Disciplina: **Mineração de Dados**
#
# Professor: **Wilson Castello Branco Neto**
#
# Aula 2 - Atividade 1: Salário por país e raça.
#
# Nome: Wilson Castello Branco Neto

# %% [markdown]
# **Dataset**: Salary dataset based on country and race
#
# Original em: https://www.kaggle.com/datasets/sudheerp2147234/salary-dataset-based-on-country-and-race
#
# Para a atividade baixe o dataset disponível no site da disciplina, pois ele sofreu algumas alterações.
#
# Após ler o dataset implemente as funções solicitadas. Sempre que for solicitada a criação de um gráfico, deve-se gerar duas versões do mesmo gráfico, uma usando o matplotlib e outra usando o seaborn.

# %% [markdown]
# 1.  Apresente as estatísticas básicas das variáveis quantitativas usando o método describe do dataframe.

# %% [markdown]
# 2.  Calcule das estatísticas básicas do atributo idade (Age) usando as funções do Pandas e compare com as geradas pelo método describe.

# %% [markdown]
# 3.  Crie o histograma de frequência para as variáveis Idade (Age) e Salário (Salary), usando a fórmula de Sturges.

# %% [markdown]
# 4. Crie o boxplot e o gráfico de violino para as coluna salário e verifique se ela possui algum outlier.

# %% [markdown]
# 5. Calcule o coeficiente de correlação (pearson) entre todas as variáveis quantitativas e analise o seu resultado. Apresente também o mapa de calor.

# %% [markdown]
# 6. Elabore o diagrama de dispersão para mostras as relações abaixo e analise os resultados, comparando com os coeficientes de correlação calculados anteriormente.
#
#
# *   Idade - Tempo de Experiência
# *   Idade - Salário
# *   Tempo de Experiência e Salário.

# %% [markdown]
# 7. Apresente a quantidade de pessoas de cada nível educacional (tabela e gráfico de colunas).

# %% [markdown]
# 8. Apresente a quantidade de pessoas por por raça (apenas o gráfico de barras)

# %% [markdown]
# 9. Apresente a quantidade de pessoas por país (apenas o gráfico de pizza)

# %% [markdown]
# 10. Apresente o salário médio agrupado por gênero (tabela e gráfico de barras)

# %% [markdown]
# 11. Apresente a variação do salário médio agrupado por gênero (gráfico de violino)

# %% [markdown]
# 12. Apresente o salário médio agrupado por nível educacional e gênero (tabela) e os gráficos de colunas. Os primeiros gráficos devem apresentar o nível educacional no eixo x e o gênero como legenda de cores e as barras devem ser agrupadas. Outro gráfico deve apresentar o gênero no eixo x e o nível educacional na legenda de cores. Este gráfico deve apresentar as colunas empilhadas.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
df = pd.read_csv('/content/gdrive/MyDrive/Ciência-de-Dados/Aula2_At1_Salary_Data_Based_country_and_race.csv')

df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2386635573.py in <cell line: 0>()
# ----> 1 df = pd.read_csv('/content/gdrive/MyDrive/Ciência-de-Dados/Aula2_At1_Salary_Data_Based_country_and_race.csv')
#       2
#       3 df
#
# NameError: name 'pd' is not defined

# %% [markdown]
# Apresente as estatísticas básicas das variáveis quantitativas usando o método describe do dataframe.

# %%
df.describe()
# Out:
#                Age  Years of Experience         Salary
# count  5118.000000          5118.000000    5118.000000
# mean     33.929660             8.265631  113722.941579
# std       7.703118             6.165074   51858.887848
# min      21.000000             0.000000   25000.000000
# 25%      28.000000             3.000000   68118.000000
# 50%      32.000000             7.000000  110707.000000
# 75%      39.000000            12.000000  160000.000000
# max      62.000000            34.000000  219000.000000

# %% [markdown]
# Calcule das estatísticas básicas do atributo idade (Age) usando as funções do Pandas e compare com as geradas pelo método describe.

# %%
quantidade = df['Age'].count()
print('Quantidade de elementos: ', quantidade)

soma = df['Age'].sum()
print('Soma dos elementos: ', soma)

media = df['Age'].mean()
print('Media dos elementos: ', media)

mediana = df['Age'].median()
print('Mediana dos elementos: ', mediana)

quartil1 = df['Age'].quantile(q=0.25)
print('Quartil 1 dos elementos: ', quartil1)

quartil2 = df['Age'].quantile(q=0.50)
print('Quartil 2 (mediana) dos elementos: ', quartil2)

quartil3 = df['Age'].quantile(q=0.75)
print('Quartil 3 dos elementos: ', quartil3)

moda = df['Age'].mode()
print('Moda dos elementos: ')
for x in moda:
  print(x)

minimo = df['Age'].min()
print('Menor valor: ', minimo)

maximo = df['Age'].max()
print('Maior valor: ', maximo)

var = df['Age'].var()
print('Variância dos elementos: ', var)

dp = df['Age'].std()
print('Desvio padrão dos elementos: ', dp)

cv = dp / media * 100
print('Coeficiente de variação dos elementos: ', cv)

assimetria = df['Age'].skew()
print('Coeficiente de assimetria: ', assimetria)

curtose = df['Age'].kurtosis()
print('Coeficiente de Curtose: ', curtose)
# Out:
# Quantidade de elementos:  5118
# Soma dos elementos:  173652.0
# Media dos elementos:  33.92966002344666
# Mediana dos elementos:  32.0
# Quartil 1 dos elementos:  28.0
# Quartil 2 (mediana) dos elementos:  32.0
# Quartil 3 dos elementos:  39.0
# Moda dos elementos:
# 27.0
# Menor valor:  21.0
# Maior valor:  62.0
# Variância dos elementos:  59.33802571984398
# Desvio padrão dos elementos:  7.703117921974451
# Coeficiente de variação dos elementos:  22.703198076996088
# Coeficiente de assimetria:  0.861144826439772
# Coeficiente de Curtose:  0.10947183333318744

# %% [markdown]
# Crie o histograma de frequência para as variáveis Idade (Age) e Salário (Salary), usando a fórmula de Sturges.

# %%
idades = df['Age']
#Fórmula de Sturges
classes = int(1 + np.log2(idades.count()))

plt.hist(idades,bins=classes, rwidth=0.98)
plt.title('Distribuição de Frequência por Idades')
plt.xlabel('Idade')
plt.ylabel('Frequência')
plt.show()

# %%
idades = df['Salary']
#Fórmula de Sturges
classes = int(1 + np.log2(idades.count()))

plt.hist(idades,bins=classes, rwidth=0.98)
plt.title('Distribuição de Frequência por Salario')
plt.xlabel('Idade')
plt.ylabel('Frequência')
plt.show()

# %% [markdown]
# Crie o boxplot e o gráfico de violino para as coluna salário e verifique se ela possui algum outlier.

# %%
df.boxplot('Salary')
plt.title('Variação da variável Salario')
plt.show()

# %%
plt.violinplot(df['Salary'])
plt.title('Violin plot')
plt.show()

# %%
sns.violinplot(y = "Salary",data = df, inner="box")
plt.title('Gráfico de violino para o atributo salário')
plt.show()

# %% [markdown]
# Calcule o coeficiente de correlação (pearson) entre todas as variáveis quantitativas e analise o seu resultado. Apresente também o mapa de calor.

# %%
df.cov(numeric_only=True)
# Out:
#                                Age  Years of Experience        Salary
# Age                      59.338026            44.455565  2.949626e+05
# Years of Experience      44.455565            38.008135  2.594268e+05
# Salary               294962.562237        259426.787556  2.689344e+09

# %%
corr = df.corr(numeric_only=True)
corr
# Out:
#                           Age  Years of Experience    Salary
# Age                  1.000000             0.936098  0.738375
# Years of Experience  0.936098             1.000000  0.811434
# Salary               0.738375             0.811434  1.000000

# %%
sns.heatmap(corr,annot=True)
plt.show()

# %% [markdown]
# Elabore o diagrama de dispersão para mostras as relações abaixo e analise os resultados, comparando com os coeficientes de correlação calculados anteriormente.
# Idade - Tempo de Experiência
# Idade - Salário
# Tempo de Experiência e Salário.

# %%
df.plot.scatter('Age','Salary', s = 20, c='red')
plt.title('Idade X Salário')
plt.xlabel('Idade')
plt.ylabel('Salário')
plt.show()

# %%
df.plot.scatter('Age','Years of Experience', s = 20, c='red')
plt.title('Idade X Tempo de Exeperiencia')
plt.xlabel('Idade')
plt.ylabel('Tempo de Exeperiencia')
plt.show()

# %%
df.plot.scatter('Years of Experience', 'Salary', s = 20, c='red')
plt.title('Tempo de Exeperiencia X Salário')
plt.xlabel('Tempo de Exeperiencia')
plt.ylabel('Salario')
plt.show()

# %% [markdown]
# Apresente a quantidade de pessoas de cada nível educacional (tabela e gráfico de colunas).

# %%
agrupadoFuncao = df.groupby(['Education Level']).size()

agrupadoFuncao
# Out:
# Education Level
# Bachelor's     2251
# High School     336
# Master's       1480
# PhD            1051
# dtype: int64

# %%
agrupadoFuncao.plot.bar('Education Level')
plt.title('Quantidade de pessoas por Nivel Educacional')
plt.xlabel('Nivel de Educacao')
plt.ylabel('Quantidade')
plt.show()

# %%
agrupadoFuncao.plot.barh('Education Level')
plt.title('Quantidade de pessoas por Nivel Educacional')
plt.xlabel('Nivel de Educacao')
plt.ylabel('Quantidade')
plt.show()

# %% [markdown]
# Apresente a quantidade de pessoas por por raça (apenas o gráfico de barras)

# %%
agrupadoFuncao = df.groupby(['Race']).size()

agrupadoFuncao
# Out:
# Race
# African American     265
# Asian               1217
# Australian           358
# Black                325
# Chinese              330
# Hispanic             259
# Korean               339
# Mixed                258
# Welsh                263
# White               1504
# dtype: int64

# %%
agrupadoFuncao.plot.barh('Race')
plt.title('Quantidade de pessoas por Nivel Educacional')
plt.xlabel('Nivel de Educacao')
plt.ylabel('Quantidade')
plt.show()

# %% [markdown]
# Apresente a quantidade de pessoas por país (apenas o gráfico de pizza)

# %%
agrupadoFuncao.plot.pie(x='Country',autopct="%.2f%%")
plt.title('Distribuição de pessoas por País')
plt.show()

# %% [markdown]
# Apresente o salário médio agrupado por gênero (tabela e gráfico de barras)

# %%
agrupadoFuncao = df.groupby(['Gender'])
salarioAgrupadoFuncao = agrupadoFuncao['Salary'].mean()
salarioAgrupadoFuncao
# Out:
# Gender
# Female    106807.706285
# Male      119543.285354
# Name: Salary, dtype: float64

# %%
salarioAgrupadoFuncao.plot.bar('Gender')
plt.title('Salário médio por Genero')
plt.xlabel('Gendero')
plt.ylabel('Salário médio')
plt.show()

# %%
salarioAgrupadoFuncao.plot.barh('Gender')
plt.title('Salário médio por Genero')
plt.xlabel('Gendero')
plt.ylabel('Salário médio')
plt.show()

# %% [markdown]
# Apresente a variação do salário médio agrupado por gênero (gráfico de violino)

# %%
sns.violinplot(x="Gender",y = "Salary",data = df, inner="box")
plt.title('Gráfico de violino para o atributo salário')
plt.show()

# %% [markdown]
# Apresente o salário médio agrupado por nível educacional e gênero (tabela) e os gráficos de colunas. Os primeiros gráficos devem apresentar o nível educacional no eixo x e o gênero como legenda de cores e as barras devem ser agrupadas. Outro gráfico deve apresentar o gênero no eixo x e o nível educacional na legenda de cores. Este gráfico deve apresentar as colunas empilhadas.

# %%
salarioAgrupadoFuncaoGenero = df.groupby(['Função','Gender'])['Salário'].mean()
salarioAgrupadoFuncaoGenero
